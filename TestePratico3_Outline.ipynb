# %% [markdown]
# <a href="https://colab.research.google.com/github/marcelounb/DeepLearning/blob/master/TestePratico3_Outline.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import tensorflow as tf
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import random 
import cv2
from cv2 import cvtColor
from google.colab.patches import cv2_imshow
import os

tf.__version__
# Out:
# '2.2.0-rc2'

# %%
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import utils

# %%
from PIL import Image, ImageFilter

# %%
path = "/content/dudu.jpg"
img_orig = Image.open(path)
img_orig
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x7F6441AB6978>

# %%
kernel_emboss = [-2,-1,0,-1,1,1,0,1,2]  # emboss

# %%
 img2 = img_orig.filter(ImageFilter.Kernel((3,3), kernel_emboss))
img2
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F64E3DCD630>

# %%
img3 = img_orig.filter(ImageFilter.BLUR)
img3  # https://pillow.readthedocs.io/en/3.3.x/reference/ImageFilter.html
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F6443CDB470>

# %%
img4 = img_orig.filter(ImageFilter.CONTOUR)
img4
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F6443CE22B0>

# %%
img5 = img_orig.filter(ImageFilter.FIND_EDGES)
img5
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F6443CE25C0>

# %%
img6 = img_orig.filter(ImageFilter.SHARPEN)
img6
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F6443CE27F0>

# %%
img7 = img_orig.filter(ImageFilter.SMOOTH_MORE)
img7
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F64E758C6A0>

# %%
img8 = img_orig.convert('LA')
img8
# Out:
# <PIL.Image.Image image mode=LA size=200x200 at 0x7F6443CE2A90>

# %%
kernel_custom_contour = [-1, -1, -1, -1, 11, -2, -2, -2, -2]  # customized contour
img9 = img_orig.filter(ImageFilter.Kernel((3,3), (kernel_custom_contour),1,0))
img9  # https://www.geeksforgeeks.org/python-pil-kernel-method/
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F6443CF4198>

# %%
img10 = cv2.imread(path)
img10 = Image.fromarray((img10 * 255).astype(np.uint8))
img10
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7F6441A82DD8>

# %%
images = []
images.append('empty')
images.append(img_orig)
images.append(img2)
images.append(img3)
images.append(img4)
images.append(img5)
images.append(img6)
images.append(img7)
images.append(img8)
images.append(img9)
images.append(img10)

# %%
legenda = []
legenda.append('Empty')
legenda.append('Original')
legenda.append('emboss')
legenda.append('BLUR')
legenda.append('CONTOUR')
legenda.append('FIND_EDGES')
legenda.append('SHARPEN')
legenda.append('SMOOTH_MORE')
legenda.append('GrayScale')
legenda.append('Custom Contour')
legenda.append('CV2 BGR+ou-')

# %%
plt.figure(figsize=(25,25))
for n in range(len(images)-1):
  plt.subplot(6,6,n+1)
  plt.imshow(images[n+1])
  plt.title(legenda[n+1])
  plt.axis('off')
